# %% [markdown]
# # CHE-226 — Midterm Examination, Fall 2025
# ### Practice copy
#
# **2 hours · 100 marks.** This is the Fall 2025 midterm with the answers removed, so you can
# attempt it and run your own code. The paper as it was actually sat is the PDF next to this
# notebook — sit that one under time first, then come back here to check your reasoning.
#
# **How to get anything out of this:** for every code cell below, write down what you think it
# prints *before* you run it. Running first and reading the output teaches you nothing that will
# be on an exam. Some cells are meant to raise an error — predict which error, then run it.
#
# Marks: Section A 20 × 1 · Section B 15 × 2 · Section C 15 × 2 · Section D 2 × 10.

# %% [markdown]
# ## Section A — Objective (20 × 1 = 20 marks)
#
# Pick one option for each. Write your answers down before checking anything.
#
# **A1.** Which of the following Python data types is immutable?
# (A) List &nbsp;(B) Tuple &nbsp;(C) Dictionary &nbsp;(D) Set
#
# **A2.** The command `import pandas as pd` is used to:
# (A) Load plotting functions &nbsp;(B) Import a data analysis library &nbsp;(C) Define a variable &nbsp;(D) Run an SQL query
#
# **A3.** Which of the following Python features makes it suitable for data analysis?
# (A) Low-level memory management &nbsp;(B) Built-in support for statistical models &nbsp;(C) Large ecosystem of libraries &nbsp;(D) Direct hardware programming
#
# **A4.** What will be printed by `print(2 * 'Data' + 'Science')`?
# (A) DataScience2 &nbsp;(B) DataDataScience &nbsp;(C) Data2Science &nbsp;(D) Error
#
# **A5.** In Python, Jupyter Notebook is mainly used for:
# (A) Writing compiled programs &nbsp;(B) Interactive code and documentation &nbsp;(C) Database management &nbsp;(D) Creating executables
#
# **A6.** Which of the following is the correct order of operations in Python?
# (A) Addition, Multiplication, Parentheses
# (B) Parentheses, Exponentiation, Multiplication/Division, Addition/Subtraction
# (C) Multiplication, Division, Addition, Parentheses
# (D) Parentheses, Addition, Multiplication
#
# **A7.** Which library is mainly used for machine learning tasks?
# (A) NumPy &nbsp;(B) Pandas &nbsp;(C) Matplotlib &nbsp;(D) Scikit-learn
#
# **A8.** In Python, the keyword used to define a function is:
# (A) func &nbsp;(B) define &nbsp;(C) def &nbsp;(D) function
#
# **A9.** What is the type of the variable created by `x = 5.0`?
# (A) int &nbsp;(B) float &nbsp;(C) str &nbsp;(D) bool
#
# **A10.** Which of the following statements assigns multiple variables in one line?
# (A) `x = 5; y = 10` &nbsp;(B) `x, y = 5, 10` &nbsp;(C) `x := 5; y := 10` &nbsp;(D) `x & y = 5, 10`

# %% [markdown]
# **A11.** In Python, what does a traceback indicate?
# (A) A successful function execution &nbsp;(B) A list of variable types &nbsp;(C) An error and where it occurred &nbsp;(D) A library import
#
# **A12.** Which of the following will correctly print text and a variable?
# (A) `print('Value is', x)` &nbsp;(B) `print('Value is' + x)` &nbsp;(C) `print('Value is' - x)` &nbsp;(D) `print('Value is' * x)`
#
# **A13.** The Python `if` statement is used to:
# (A) Define a loop &nbsp;(B) Perform conditional execution &nbsp;(C) Create a variable &nbsp;(D) Import libraries
#
# **A14.** Which of the following demonstrates chained comparison?
# (A) `x > 5 < 10` &nbsp;(B) `x > 5and < 10` &nbsp;(C) `5 < x > 10` &nbsp;(D) `x = 5 < 10`
#
# **A15.** What is the result of `7 // 3` in Python?
# (A) 2.33 &nbsp;(B) 2 &nbsp;(C) 1 &nbsp;(D) 3
#
# **A16.** What is the result of `7 / 3` in Python?
# (A) 2.33 &nbsp;(B) 2 &nbsp;(C) 2.0 &nbsp;(D) 3
#
# **A17.** Which Python data type can store heterogeneous elements?
# (A) List &nbsp;(B) Tuple &nbsp;(C) Set &nbsp;(D) All of the above
#
# **A18.** Which library is mainly used for numerical computations?
# (A) NumPy &nbsp;(B) Pandas &nbsp;(C) Matplotlib &nbsp;(D) Seaborn
#
# **A19.** Which of the following is the correct syntax for an if-else statement?
# (A) `if x > 5: print(x) else: print(0)`
# (B) `if x > 5 print(x) else print(0)`
# (C) `if x > 5: print(x) \else: print(0)`
# (D) `if x > 5: print(x)`
#
# **A20.** Which of the following statements about Python tuples is correct?
# (A) Tuples are mutable and can be changed after creation
# (B) Tuples can contain elements of different data types
# (C) Tuples do not allow duplicate elements
# (D) Tuples have no indexing support

# %% [markdown]
# ## Section B (CLO-1, C2) — Code tracing and output (15 × 2 = 30 marks)
#
# Predict the output of each cell first, then run it.

# %% [markdown]
# **B1.** Comprehend the following code by creating the variables `x = 2` and `y = 3`, then determine what each of the statements below will display:

# %%
x = 2
y = 3
print('x =', x)
print('Value of', x, '+', x, 'is', (x + x))
print('x =')
print((x + y), 'x =', (y + x))

# %% [markdown]
# **B2.** Predict the output of the following program and explain its pattern:

# %%
for row in range(10):
    for column in range(10):
        print('<' if row % 2 == 1 else '>', end='')
    print()

# %% [markdown]
# **B3.** Fill in the missing code below so that the program prints two rows, each containing seven `@` symbols. Rewrite the nested loops by providing the correct ranges:

# %%
# Replace each *** with the correct range
for ***:
    for ***:
        print('@', end='')
    print()

# %% [markdown]
# **B4.** What does the following function do if passed the list `[1, 2, 3, 4, 5]`? Interpret the code logic:

# %%
def mystery(x):
    y = 0
    for value in x:
        y += value ** 2
    return y

mystery([1, 2, 3, 4, 5])

# %% [markdown]
# **B5.** Distinguish whether the following function determines if a sequence is sorted:

# %%
def mystery(sequence):
    return sequence == sorted(sequence)

mystery([1, 2, 3])
mystery([3, 1, 2])

# %% [markdown]
# **B6.** Replace the `***` in the following code so that a list of heights in inches is converted into values in metres (1 inch = 0.0254 m). Generalize the pattern:

# %%
[*** for x in [69, 77, 54]]

list(map(lambda ***, [69, 77, 54]))

# %% [markdown]
# **B7.** Summarize the output of this nested loop that prints a multiplication table:

# %%
for i in range(1, 4):
    for j in range(1, 4):
        print(i*j, end=' ')
    print()

# %% [markdown]
# **B8.** Translate the logic of the following function and determine its output:

# %%
def filter_even(lst):
    return [x for x in lst if x % 2 == 0]

filter_even([1, 2, 3, 4, 5, 6])

# %% [markdown]
# **B9.** Explain the formatted print statement below and give an example of its output:

# %%
name = 'Alice'
score = 95
print(f"Name: {name}, Score: {score}")

# %% [markdown]
# **B10.** Estimate the output of the following nested list comprehension:

# %%
matrix = [[i*j for j in range(3)] for i in range(3)]
print(matrix)

# %% [markdown]
# **B11.** What will the following code print? Infer the boolean logic and justify:

# %%
x = 5
y = 10
z = 7
print(x < z < y)

# %% [markdown]
# **B12.** Interpret the output of the following slicing operations:

# %%
nums = [1, 2, 3, 4, 5]
print(nums[1:4])
print(nums[:3])
print(nums[::2])

# %% [markdown]
# **B13.** Explain the result of the following boolean expression:

# %%
a = True
b = False
print(a and not b or b)

# %% [markdown]
# **B14.** Demonstrate what the following code displays:

# %%
s = 'Py'
print(s*3 + 'thon')

# %% [markdown]
# **B15.** Infer the output of this nested loop snippet:

# %%
for i in range(2):
    for j in range(3):
        print(i, j)

# %% [markdown]
# ## Section C (CLO-1, C2) — Debugging and short questions (15 × 2 = 30 marks)
#
# Several of these cells raise an error on purpose, and a few are perfectly correct — deciding which
# is which is the question. Name the error (and the line) before you run anything.

# %% [markdown]
# **C1.** Comprehend the following code intended to calculate the average of a list, and identify its errors:

# %%
values = [10, 20, 30, 40]
sum_val = 0
for i in range(len(values)):
    sum_val = sum_val + values[i]
avg = sum_val / len(values)
print(avg)

# %% [markdown]
# **C2.** Estimate a Python code to read five numbers from a user and determine their maximum and minimum **without** using the built-in `max()` or `min()`.

# %%
# Your code here

# %% [markdown]
# **C3.** Distinguish the problem in this tuple assignment:

# %%
day, high_temperature = ('Monday', 87, 65)

# %% [markdown]
# **C4.** Predict the error in this code snippet:

# %%
numbers = [1, 2, 3, 4, 5]
numbers[10]

# %% [markdown]
# **C5.** Interpret the problem in the following string assignment:

# %%
name = 'amanda'
name[0] = 'A'

# %% [markdown]
# **C6.** Explain what is wrong here:

# %%
numbers = [1, 2, 3, 4, 5]
numbers[3.4]

# %% [markdown]
# **C7.** Identify the error in this tuple operation:

# %%
student_tuple = ('Amanda', 'Blue', [98, 75, 87])
student_tuple[0] = 'Ariana'

# %% [markdown]
# **C8.** Infer what is wrong with the following concatenation:

# %%
('Monday', 87, 65) + ('Tuesday',)

# %% [markdown]
# **C9.** Explain the problem in this augmented assignment:

# %%
a = 'A'
a += 'B'

# %% [markdown]
# **C10.** Interpret what happens when deleting a variable:

# %%
x = 7
del x
print(x)

# %% [markdown]
# **C11.** Distinguish the error when searching for a missing element in a list:

# %%
numbers = [1, 2, 3, 4, 5]
numbers.index(10)

# %% [markdown]
# **C12.** Comprehend what is wrong with this extend operation:

# %%
numbers = [1, 2, 3, 4, 5]
numbers.extend([6, 7, 8])

# %% [markdown]
# **C13.** Explain the error when removing a non-existent element:

# %%
numbers = [1, 2, 3, 4, 5]
numbers.remove(10)

# %% [markdown]
# **C14.** Predict the error that occurs when popping from an empty list:

# %%
values = []
values.pop()

# %% [markdown]
# **C15.** Translate the following cube function and identify what is missing:

# %%
def cube(x):
    """Calculate the cube of x."""
    return x ** 3

print('The cube of 2 is', cube(2))

# %% [markdown]
# ## Section D (CLO-1, C2) — Conceptual reasoning (2 × 10 = 20 marks)
#
# These two were set to be solved **on paper** — the marks are for the steps, not for a working
# program. Write the steps out first; the code cell underneath is only for checking yourself
# afterwards.

# %% [markdown]
# **D1.** Given the list of numbers:
#
# ```
# [6, 3, 5, 3, 2, 6, 4, 1, 5, 2, 7]
# ```
#
# Summarize the steps you would take to perform the following tasks on paper:
#
# 1. Remove all duplicate elements while preserving the original order.
# 2. Sort the resulting list in ascending order.
# 3. Determine whether the final list forms a sequence of consecutive integers. If not, list the missing values.

# %%
lst = [6, 3, 5, 3, 2, 6, 4, 1, 5, 2, 7]
# Steps on paper first. Check yourself here afterwards.

# %% [markdown]
# **D2.** You are given the list:
#
# ```
# [12, 7, 5, 20, 15, 8, 3]
# ```
#
# Translate the following into paper-solvable steps:
#
# 1. Write a lambda function (or describe its logic) to select only numbers divisible by 5.
# 2. Use the lambda function with the concept of `filter()` to create a new list of these numbers.
# 3. Sort the resulting list in descending order and write it down.

# %%
lst = [12, 7, 5, 20, 15, 8, 3]
# Steps on paper first. Check yourself here afterwards.

# %% [markdown]
# *— End of paper —*
